# %% [markdown]
# <a href="https://colab.research.google.com/github/meena-shankar/E-commerce-Review-Sentiment-Analysis/blob/main/Text_Mining_and_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
path='/content/drive/My Drive/dataset/Clothing Reviews.csv'
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age  ...   Division Name Department Name  Class Name
# 0           0          767   33  ...       Initmates        Intimate   Intimates
# 1           1         1080   34  ...         General         Dresses     Dresses
# 2           2         1077   60  ...         General         Dresses     Dresses
# 3           3         1049   50  ...  General Petite         Bottoms       Pants
# 4           4          847   47  ...         General            Tops     Blouses
#
# [5 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating',
#        'Recommended IND', 'Positive Feedback Count', 'Division Name',
#        'Department Name', 'Class Name'],
#       dtype='object')

# %%
df.drop(["Clothing ID", "Title"], axis=1, inplace=True)
df.head()
# Out:
#    Unnamed: 0  Age  ... Department Name  Class Name
# 0           0   33  ...        Intimate   Intimates
# 1           1   34  ...         Dresses     Dresses
# 2           2   60  ...         Dresses     Dresses
# 3           3   50  ...         Bottoms       Pants
# 4           4   47  ...            Tops     Blouses
#
# [5 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# Age                          0
# Review Text                845
# Rating                       0
# Recommended IND              0
# Positive Feedback Count      0
# Division Name               14
# Department Name             14
# Class Name                  14
# dtype: int64

# %%
len(df)
# Out:
# 23486

# %%
df.describe()
# Out:
#          Unnamed: 0           Age  ...  Recommended IND  Positive Feedback Count
# count  23486.000000  23486.000000  ...     23486.000000             23486.000000
# mean   11742.500000     43.198544  ...         0.822362                 2.535936
# std     6779.968547     12.279544  ...         0.382216                 5.702202
# min        0.000000     18.000000  ...         0.000000                 0.000000
# 25%     5871.250000     34.000000  ...         1.000000                 0.000000
# 50%    11742.500000     41.000000  ...         1.000000                 1.000000
# 75%    17613.750000     52.000000  ...         1.000000                 3.000000
# max    23485.000000     99.000000  ...         1.000000               122.000000
#
# [8 rows x 5 columns]

# %%
df['Age'].unique()
# Out:
# array([33, 34, 60, 50, 47, 49, 39, 24, 53, 44, 41, 32, 55, 31, 28, 46, 21,
#        36, 65, 29, 38, 59, 40, 23, 67, 48, 43, 52, 56, 66, 61, 57, 58, 37,
#        27, 62, 68, 51, 83, 69, 54, 63, 71, 30, 35, 64, 42, 22, 26, 72, 25,
#        45, 74, 70, 20, 80, 93, 82, 77, 85, 73, 78, 79, 19, 76, 84, 75, 89,
#        81, 90, 94, 86, 99, 18, 91, 87, 92])

# %%
df['Class Name'].unique()
# Out:
# array(['Intimates', 'Dresses', 'Pants', 'Blouses', 'Knits', 'Outerwear',
#        'Lounge', 'Sweaters', 'Skirts', 'Fine gauge', 'Sleep', 'Jackets',
#        'Swim', 'Trend', 'Jeans', 'Legwear', 'Shorts', 'Layering',
#        'Casual bottoms', nan, 'Chemises'], dtype=object)

# %%
df['Recommended IND'].unique()
# Out:
# array([1, 0])

# %%
df['Division Name'].unique()
# Out:
# array(['Initmates', 'General', 'General Petite', nan], dtype=object)

# %%
df['Division Name'].unique()
# Out:
# array(['Initmates', 'General', 'General Petite', nan], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Sentiment Analysis

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
df.dtypes
# Out:
# Unnamed: 0                  int64
# Age                         int64
# Review Text                object
# Rating                      int64
# Recommended IND             int64
# Positive Feedback Count     int64
# Division Name              object
# Department Name            object
# Class Name                 object
# dtype: object

# %%
df['Review Text'].head()
# Out:
# 0    Absolutely wonderful - silky and sexy and comf...
# 1    Love this dress!  it's sooo pretty.  i happene...
# 2    I had such high hopes for this dress and reall...
# 3    I love, love, love this jumpsuit. it's fun, fl...
# 4    This shirt is very flattering to all due to th...
# Name: Review Text, dtype: object

# %%
df['Review Text'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# Removing the rows that has null values

# %%
df = df[~df['Review Text'].isnull()]

# %%
df['length']=df['Review Text'].apply(len)

# %%
df.head()
# Out:
#    Unnamed: 0  Age  ... Class Name  length
# 0           0   33  ...  Intimates      53
# 1           1   34  ...    Dresses     303
# 2           2   60  ...    Dresses     500
# 3           3   50  ...      Pants     124
# 4           4   47  ...    Blouses     192
#
# [5 rows x 10 columns]

# %% [markdown]
# Length after removing the rows where Review Text is null

# %%
len(df)
# Out:
# 22641

# %% [markdown]
# **Length of the messages based on Recommended IND**

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='Recommended IND',y='length',data=df,hue='Rating',palette='rainbow')
plt.title('message length')
# Out:
# Text(0.5, 1.0, 'message length')

# %%
df.length.describe()
# Out:
# count    22641.000000
# mean       308.687911
# std        143.940048
# min          9.000000
# 25%        186.000000
# 50%        301.000000
# 75%        459.000000
# max        508.000000
# Name: length, dtype: float64

# %% [markdown]
# maximum length is 508.

# %% [markdown]
# **Maximum length review**

# %%
df[df['length'] == 508]['Review Text'].iloc[0]
# Out:
# 'I adore this blouse. the colors are vibrant (see my photo below). this is one of my favorite purchases from retailer. the top is light weight. true to size. i ordered a petite small and am 5 feet tall 120 lbs. and curvy. i left it untucked and loose like in the photo and it was very flattering. i disagree about it being frumpy. i wore it with kelly green retailer brand slacks paired with the retailer yellow sweater coat with white piping, and the retailer moss suede cross bag and neutral color (nude) fl'

# %% [markdown]
# **Removing puntuations**

# %%
import string
string.punctuation
def remove_punctuation(text):
    no_punct=[words for words in text if words not in string.punctuation]
    words_wo_punct=''.join(no_punct)
    return words_wo_punct
df['Review Text']=df['Review Text'].apply(lambda x: remove_punctuation(x))
df.head()
# Out:
#    Unnamed: 0  Age  ... Class Name  length
# 0           0   33  ...  Intimates      53
# 1           1   34  ...    Dresses     303
# 2           2   60  ...    Dresses     500
# 3           3   50  ...      Pants     124
# 4           4   47  ...    Blouses     192
#
# [5 rows x 10 columns]

# %% [markdown]
# **Text blob for polarity**

# %% [markdown]
# Using polarity we can classifity the reviews with as Positive, Negative or Neutral.

# %%
from textblob import TextBlob
df.head()
# Out:
#    Unnamed: 0  Age  ... Class Name  length
# 0           0   33  ...  Intimates      53
# 1           1   34  ...    Dresses     303
# 2           2   60  ...    Dresses     500
# 3           3   50  ...      Pants     124
# 4           4   47  ...    Blouses     192
#
# [5 rows x 10 columns]

# %%
df["Polarity"] = df["Review Text"].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
df.head()
# Out:
#    Unnamed: 0  Age  ... length  Polarity
# 0           0   33  ...     53  0.633333
# 1           1   34  ...    303  0.318750
# 2           2   60  ...    500  0.076392
# 3           3   50  ...    124  0.500000
# 4           4   47  ...    192  0.393750
#
# [5 rows x 11 columns]

# %%
df['Polarity'].min()
# Out:
# -0.9750000000000001

# %%
df['Polarity'].mean()
# Out:
# 0.24147953735572483

# %%
import plotly.express as px

# %%
px.histogram(df, x='Polarity', opacity = 0.5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="99990e2d-e206-4b94-84f1-1c751e92e1b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById
666666666666665, 0.16635101010101008, 0.08773001508295626, 0.15093537414965988, 0.1559259259259259, 0.37723214285714285, 0.25, 0.20914115646258505, 0.4325396825396825, 0.16835753532182104, 0.15476190476190477, 0.2958333333333333, 0.0625, 0.09947916666666667, 0.1907814407814408, 0.24374999999999997, 0.18791666666666665, 0.130952380952381, -0.08583333333333333, 0.22999999999999998, 0.2734848484848485, 0.10965419501133786, 0.2575, 0.23000000000000004, 0.24090909090909093, 0.24380952380952384, 0.2310267857142857, 0.2593489843489844, 0.39944444444444444, 0.21666666666666665, 0.22857142857142862, 0.3616666666666667, 0.32999999999999996, 0.038333333333333344, 0.17857142857142858, 0.5666666666666668, 0.13333333333333333, 0.06597222222222222, 0.22870370370370374, 0.6, 0.16562499999999997, 0.3044688644688645, 0.24768518518518523, 0.23958333333333334, 0.2, 0.2972222222222222, 0.10357142857142858, 0.2783333333333333, 0.35, -0.06785714285714285, 0.0010204081632652986, 0.042142857142857135, 0.22297619047619047, 0.15833333333333333, 0.12000000000000002, 0.17777777777777778, 0.3931428571428571, 0.2525510204081633, 0.2504378434065935, 0.1722283272283272, 0.3245179063360882, 0.16741071428571427, 0.06655555555555555, 0.24425, 0.31249999999999994, 0.3300595238095238, 0.12696078431372546, 0.0236111111111111, 0.36441798941798953, 0.14564285714285713, 0.25937499999999997, -0.05500000000000001, 0.1515625, 0.07333333333333335, 0.3503968253968 ...

# %%
def getAnalysis(polarity):
  if polarity < 0:
    return 'Negative'
  elif polarity == 0:
    return 'Neutral'
  else:
    return 'Positive'

# %%
 df['TextBlob_Analysis']=df['Polarity'].apply(getAnalysis)

# %%
df.head()
# Out:
#    Unnamed: 0  Age  ...  Polarity  TextBlob_Analysis
# 0           0   33  ...  0.633333           Positive
# 1           1   34  ...  0.318750           Positive
# 2           2   60  ...  0.076392           Positive
# 3           3   50  ...  0.500000           Positive
# 4           4   47  ...  0.393750           Positive
#
# [5 rows x 12 columns]

# %%
polarity_plot=df['TextBlob_Analysis'].value_counts()

# %%
polarity_plot
# Out:
# Positive    21213
# Negative     1333
# Neutral        95
# Name: TextBlob_Analysis, dtype: int64

# %% [markdown]
# **Plot for polarity based on Recommended IND**

# %%
sns.countplot(data=df, x='TextBlob_Analysis', hue='Recommended IND', palette='rainbow')

# %% [markdown]
# The product recommeded are given a value '1' and they are in positive polarity.

# %% [markdown]
# **Pie Chart for polarity**

# %%
positive= 21213/len(df)*100
negative= 1333/len(df)*100
neutral= 95/len(df)*100

# %%
labels = ['Positive', 'Negative', 'Neutral']
sizes = [positive, negative, neutral]
plt.figure(figsize=(12,7))
plt.pie(sizes, labels=labels,autopct='%1.1f%%',shadow=True, startangle=140)
plt.show()

# %% [markdown]
# ***Bar plot for polarity***

# %%
plt.figure(figsize=(10,8))
sns.barplot(polarity_plot.index, polarity_plot.values)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ***Label Encoding***

# %%
 #Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['Encoded_value']= label_encoder.fit_transform(df['TextBlob_Analysis'])
  
df['Encoded_value'].unique()
# Out:
# array([2, 0, 1])

# %%
df.head(5)
# Out:
#    Unnamed: 0  Age  ... TextBlob_Analysis  Encoded_value
# 0           0   33  ...          Positive              2
# 1           1   34  ...          Positive              2
# 2           2   60  ...          Positive              2
# 3           3   50  ...          Positive              2
# 4           4   47  ...          Positive              2
#
# [5 rows x 13 columns]

# %%
df[df['TextBlob_Analysis']=='Negative']['Encoded_value'].head()
# Out:
# 10    0
# 14    0
# 22    0
# 44    0
# 72    0
# Name: Encoded_value, dtype: int64

# %% [markdown]
# Negative reviews are given 0 as encoded value, Positive as 2 and Neutral as 1

# %%
sns.boxplot(x="Rating", y="length", data=df,)

# %% [markdown]
# From the boxplot below,neutral Reviews(encoded value 0) length are smaller than the positive and negative reviews.

# %%
sns.boxplot(x="Encoded_value", y="length", data=df,)

# %% [markdown]
# we can infer that, negative reviews( encoded value 0) are of a rating around 3, whereas the neutral reviews are with a rating around 3.5 and positive reviews are around 4.2

# %% [markdown]
# # ***Word Cloud***

# %% [markdown]
# we are splitting the dataframe based on the negative and positive reviews. To generate a word cloud of word which has a positive impact, we are creating a 'for loop' that iterates in the review column.

# %% [markdown]
# ***Splitting into two data frames***

# %%
df_positive = df[df["TextBlob_Analysis"] == "Positive"]
df_negative = df[df["TextBlob_Analysis"] == "Negative"]

# %%
df_negative['Polarity']=df_negative['Polarity'].astype(float)
df_positive['Polarity']=df_positive['Polarity'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_positive.head()
# Out:
#    Unnamed: 0  Age  ... TextBlob_Analysis  Encoded_value
# 0           0   33  ...          Positive              2
# 1           1   34  ...          Positive              2
# 2           2   60  ...          Positive              2
# 3           3   50  ...          Positive              2
# 4           4   47  ...          Positive              2
#
# [5 rows x 13 columns]

# %%
from wordcloud import WordCloud, STOPWORDS

comment_words = ''
stopwords = set(STOPWORDS)
  
# iterate through the csv file
for val in df_positive["Review Text"]:
      
    # typecaste each val to string
    val = str(val)
  
    # split the value
    tokens = val.split()
      
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 400, height = 400,
                background_color ='pink',max_words=100,
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
  
# plot the WordCloud image                       
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()

# %%
#save image of word cloud
#wordcloud.to_file("img/first_review.png")

# %% [markdown]
# ***Finding top positive words and bigrams***

# %%
df['Polarity']=df['Polarity'].astype(float)

# %% [markdown]
# # **Finding frequent positive and negative words**

# %%
df_negative.head()
# Out:
#     Unnamed: 0  Age  ... TextBlob_Analysis  Encoded_value
# 10          10   53  ...          Negative              0
# 14          14   50  ...          Negative              0
# 22          22   31  ...          Negative              0
# 44          44   48  ...          Negative              0
# 72          72   27  ...          Negative              0
#
# [5 rows x 13 columns]

# %%
import numpy as np
import nltk
from nltk import word_tokenize
from nltk import ngrams
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
nltk.download("stopwords")
stop_words = set(stopwords.words('english'))
import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df['Review Text'] = df['Review Text'].astype(str)

# %%
def text_process(mess):
  nopunc = [char for char in mess if char not in string.punctuation]
  nopunc = ''.join(nopunc)
  words= [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
  return words

# %%
df_positive['Review Text'].apply(text_process)
df_positive['Review_text_cleaned']=df['Review Text'].apply(text_process)

# %%
df_positive.head()
# Out:
#    Unnamed: 0  ...                                Review_text_cleaned
# 0           0  ...  [Absolutely, wonderful, silky, sexy, comfortable]
# 1           1  ...  [Love, dress, sooo, pretty, happened, find, st...
# 2           2  ...  [high, hopes, dress, really, wanted, work, ini...
# 3           3  ...  [love, love, love, jumpsuit, fun, flirty, fabu...
# 4           4  ...  [shirt, flattering, due, adjustable, front, ti...
#
# [5 rows x 14 columns]

# %%
df_positive['Review_text_cleaned']=df_positive['Review_text_cleaned'].astype(str)

# %%
import heapq
from operator import itemgetter
from collections import Counter

def Top50(data,title=None):
    token_data= []
    tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
    for i in data:
        l = tokenizer.tokenize(i)
        token_data.append(l)
    corpus = []
    for i in token_data:
       for j in i:
         corpus.append(j)
    c = Counter(corpus)
    Di = dict(c)
    Top_50 = dict(heapq.nlargest(50, Di.items(), key=itemgetter(1)))
    dd = pd.DataFrame(Top_50.items(),columns=["word","frequency"])
    fig = plt.figure(1, figsize=(15, 15))
    plt.bar(range(len(Top_50)),Top_50.values(),align='center')        
    plt.xticks(range(len(Top_50)), list(Top_50.keys()))
    plt.tick_params(axis="x",rotation=90) 
    plt.tight_layout(pad = 0)
    if title==None:
        plt.title("Top 50 words")
    else:
        plt.title(title)
    return dd.head(10)

# %% [markdown]
# ***Frequently used positive words***

# %%
Top50(df_positive["Review_text_cleaned"],title="Top 50 Positive words")
top_positive_words=Top50(df_positive["Review_text_cleaned"],title="Top 50 Positive words")
top_positive_words
# Out:
#     word  frequency
# 0  dress       9837
# 1   size       8146
# 2   love       7684
# 3    top       7167
# 4    fit       7012
# 5   like       6410
# 6   wear       6081
# 7  great       5705
# 8     im       5224
# 9  would       4707

# %% [markdown]
# ***Frequent negative words***

# %%
df_negative['Review Text'].apply(text_process)
df_negative['Review_text_cleaned']=df_negative['Review Text'].apply(text_process)

# %%
df_negative['Review_text_cleaned']=df_negative['Review_text_cleaned'].astype(str)

# %%
Top50(df_negative["Review_text_cleaned"],title="Top 50 Negative words")
top_negative_words=Top50(df_negative["Review_text_cleaned"],title="Top 50 negative words")
top_negative_words
# Out:
#      word  frequency
# 0   dress        555
# 1    size        521
# 2   small        494
# 3    like        489
# 4    wear        321
# 5  fabric        299
# 6   would        289
# 7      im        281
# 8    back        277
# 9  little        271

# %%
def text_preprocessing(words):
    tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
    nopunc = clean_text(text)
    tokenized_text = tokenizer.tokenize(nopunc)
    remove_stopwords = [w for w in tokenized_text if w not in stopwords.words('english')]
    combined_text = ' '.join(remove_stopwords)
    return combined_text

# %% [markdown]
# ***Bi-grams***

# %%
df['Review Text'].apply(text_process)
df['Review_text_cleaned']=df['Review Text'].apply(text_process)

# %%
df.head()
# Out:
#    Unnamed: 0  ...                                Review_text_cleaned
# 0           0  ...  [Absolutely, wonderful, silky, sexy, comfortable]
# 1           1  ...  [Love, dress, sooo, pretty, happened, find, st...
# 2           2  ...  [high, hopes, dress, really, wanted, work, ini...
# 3           3  ...  [love, love, love, jumpsuit, fun, flirty, fabu...
# 4           4  ...  [shirt, flattering, due, adjustable, front, ti...
#
# [5 rows x 14 columns]

# %%
df['Review_text_cleaned']=df['Review_text_cleaned'].astype(str)

# %%
def Ngram(data,num,title=None):
    token_data= []
    tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
    for i in data:
        n_grams = ngrams(tokenizer.tokenize(i), num)
        p = [ ' '.join(grams) for grams in  n_grams]
        token_data.append(p)
    corpus = []
    for i in token_data:
       for j in i:
         corpus.append(j)
    c = Counter(corpus)
    Di = dict(c)
    Top_50 = dict(heapq.nlargest(50, Di.items(), key=itemgetter(1)))
    dd = pd.DataFrame(Top_50.items(),columns=["word","frequency"])
    fig = plt.figure(1, figsize=(15, 15))
    plt.bar(range(len(Top_50)),Top_50.values(),align='center')        
    plt.xticks(range(len(Top_50)), list(Top_50.keys()))
    plt.tick_params(axis="x",rotation=90) 
    plt.tight_layout(pad = 0)
    if title==None:       
        plt.title("Ngram")
    else:
        plt.title(title)
    return dd.head(10)

# %%
Ngram(df["Review_text_cleaned"],2,title="Bigram of Reviews")
# Out:
#              word  frequency
# 0       true size       1283
# 1    usually wear        683
# 2     looks great        605
# 3      love dress        604
# 4   fit perfectly        598
# 5       well made        501
# 6      size small        478
# 7      usual size        475
# 8  fits perfectly        475
# 9       look like        408

# %% [markdown]
# ***Bigram of positive review***

# %%
Ngram(df_positive["Review_text_cleaned"],2,title="Bigram of Positive Reviews")
# Out:
#              word  frequency
# 0       true size       1257
# 1    usually wear        618
# 2     looks great        602
# 3   fit perfectly        596
# 4      love dress        591
# 5       well made        477
# 6  fits perfectly        471
# 7      usual size        443
# 8      size small        428
# 9        love top        384

# %% [markdown]
# ***Bi-grams for Negative Reviewa***

# %%
Ngram(df_negative["Review_text_cleaned"],2,title="Bigram of Negative Reviews")
# Out:
#            word  frequency
# 0  usually wear         64
# 1    going back         54
# 2    size small         47
# 3    runs small         40
# 4   looked like         40
# 5    looks like         35
# 6     look like         35
# 7    usual size         31
# 8  regular size         31
# 9        size 6         28

# %% [markdown]
# # **correlation heatmap**

# %%
df.head()
# Out:
#    Unnamed: 0  ...                                Review_text_cleaned
# 0           0  ...  ['Absolutely', 'wonderful', 'silky', 'sexy', '...
# 1           1  ...  ['Love', 'dress', 'sooo', 'pretty', 'happened'...
# 2           2  ...  ['high', 'hopes', 'dress', 'really', 'wanted',...
# 3           3  ...  ['love', 'love', 'love', 'jumpsuit', 'fun', 'f...
# 4           4  ...  ['shirt', 'flattering', 'due', 'adjustable', '...
#
# [5 rows x 14 columns]

# %%
df=df.drop(['Unnamed: 0','Positive Feedback Count'], axis=1)

# %%
df.head()
# Out:
#    Age  ...                                Review_text_cleaned
# 0   33  ...  ['Absolutely', 'wonderful', 'silky', 'sexy', '...
# 1   34  ...  ['Love', 'dress', 'sooo', 'pretty', 'happened'...
# 2   60  ...  ['high', 'hopes', 'dress', 'really', 'wanted',...
# 3   50  ...  ['love', 'love', 'love', 'jumpsuit', 'fun', 'f...
# 4   47  ...  ['shirt', 'flattering', 'due', 'adjustable', '...
#
# [5 rows x 12 columns]

# %%
df.groupby('Encoded_value').count()
# Out:
#                  Age  Review Text  ...  TextBlob_Analysis  Review_text_cleaned
# Encoded_value                      ...
# 0               1333         1333  ...               1333                 1333
# 1                 95           95  ...                 95                   95
# 2              21213        21213  ...              21213                21213
#
# [3 rows x 11 columns]

# %%
df.groupby('Encoded_value').mean()
# Out:
#                      Age    Rating  Recommended IND      length  Polarity
# Encoded_value
# 0              43.362341  2.957989         0.431358  297.592648 -0.092062
# 1              42.452632  3.400000         0.610526  134.452632  0.000000
# 2              43.278933  4.264083         0.844152  310.165417  0.263520

# %% [markdown]
# ***Heatmap***

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.groupby('Encoded_value').mean().corr(), annot=True)

# %% [markdown]
# ***Cluster map***

# %%
plt.figure(figsize=(8,6))
sns.clustermap(df.groupby('Encoded_value').mean().corr(), annot=True, cmap='viridis')
